# %% [markdown]
# # mysql -> mongodb
# - create sql_connect_obj
# - read_sql to pd
#
#
# - create client for mongodb
# - access to collection(table)
# - transfrom pd_data
# - insert_many
#
# # mongodb -> mysql
# - create collection obj
# - collection.find and to pd
#
#
# - execute query(charset)
# - create engine by sqlalchemy
# - to_sql

# %%
import MySQLdb, pymongo
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### mysql -> mongodb
# - connect obj

# %%
db = MySQLdb.connect("00.00.00.000",
                     "account",
                     "password",
                     "database",
                     charset="utf8"
                    )
db
# Out:
# <_mysql.connection open to '52.79.146.220' at 563c329f9bb8>

# %% [markdown]
# - sql -> pd

# %%
query = """
    select *
    from country
"""
cdf = pd.read_sql(query, db)
cdf.tail()
# Out:
#     Code          Name Continent           Region  SurfaceArea  IndepYear  \
# 234  YEM         Yemen      Asia      Middle East     527968.0     1918.0
# 235  YUG    Yugoslavia    Europe  Southern Europe     102173.0     1918.0
# 236  ZAF  South Africa    Africa  Southern Africa    1221037.0     1910.0
# 237  ZMB        Zambia    Africa   Eastern Africa     752618.0     1964.0
# 238  ZWE      Zimbabwe    Africa   Eastern Africa     390757.0     1980.0
#
#      Population  LifeExpectancy       GNP    GNPOld     LocalName  \
# 234    18112000            59.8    6041.0    5729.0      Al-Yaman
# 235    10640000            72.4   17000.0       NaN   Jugoslavija
# 236    40377000            51.1  116729.0  129092.0  South Africa
# 237     9169000            37.2    3377.0    3922.0        Zambia
# 238    11669000            37.8    5951.0    8670.0      Zimbabwe
#
#        GovernmentForm         HeadOfState  Capital Code2
# 234          Republic  Ali Abdallah Salih   1780.0    YE
# ...

# %% [markdown]
# - mongo 접근

# %%
client = pymongo.MongoClient('mongodb://00.00.00.000')
collection = client.world.country
collection
# Out:
# Collection(Database(MongoClient(host=['52.79.146.220:27017'], document_class=dict, tz_aware=False, connect=True), 'world'), 'country')

# %%
# transform data for fowarding to Mongodb
data = cdf.to_dict('records')
len(data)
# Out:
# 239

# %%
result = collection.insert_many(data)
result

# %%
data
# Out:
# [{'Code': 'ABW',
#   'Name': 'Aruba',
#   'Continent': 'North America',
#   'Region': 'Caribbean',
#   'SurfaceArea': 193.0,
#   'IndepYear': nan,
#   'Population': 103000,
#   'LifeExpectancy': 78.4,
#   'GNP': 828.0,
#   'GNPOld': 793.0,
#   'LocalName': 'Aruba',
#   'GovernmentForm': 'Nonmetropolitan Territory of The Netherlands',
#   'HeadOfState': 'Beatrix',
#   'Capital': 129.0,
#   'Code2': 'AW',
#   '_id': ObjectId('5c126b9401849f5486b9f564')},
#  {'Code': 'AFG',
#   'Name': 'Afghanistan',
#   'Continent': 'Asia',
#   'Region': 'Southern and Central Asia',
#   'SurfaceArea': 652090.0,
#   'IndepYear': 1919.0,
#   'Population': 22720000,
#   'LifeExpectancy': 45.9,
#   'GNP': 5976.0,
#   'GNPOld': nan,
#   'LocalName': 'Afganistan/Afqanestan',
#   'GovernmentForm': 'Islamic Emirate',
#   'HeadOfState': 'Mohammad Omar',
#   'Capital': 1.0,
#   'Code2': 'AF',
#   '_id': ObjectId('5c126b9401849f5486b9f565')},
#  {'Code': 'AGO',
#   'Name': 'Angola',
#   'Continent': 'Africa',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### mongodb -> mysql
# - create collection obj
# - collection.find and to pd
#
#
# - execute query(charset)
# - create engine by sqlalchemy
# - to_sql

# %%
collection = client.practice.pr1
collection
# Out:
# Collection(Database(MongoClient(host=['52.79.146.220:27017'], document_class=dict, tz_aware=False, connect=True), 'practice'), 'pr1')

# %%
docs = collection.find(
    filter={},
    projection={
        "_id": False,
        "size": True
    }
)

df = pd.DataFrame(list(docs))
df.head()
# Out:
#    size
# 0  12.0
# 1  11.0
# 2  15.0
# 3  14.0
# 4   6.2

# %%
query = """
ALTER DATABASE world CHARACTER SET = utf8;
"""
cur = db.cursor()
cur.execute(query)
# Out:
# 1

# %%
engine = create_engine("mysql://account:password@52.79.146.220/databa?charset=utf8")
engine
# Out:
# Engine(mysql://root:***@52.79.146.220/world?charset=utf8)

# %%
df.to_sql("practice", con=engine, if_exists="replace")

# %% [markdown]
# # 번외

# %% [markdown]
# - sql -> pd

# %%
query = """
select size
from practice;
"""
cur.execute(query)
# Out:
# 415

# %%
# iterator:일회용
rows = cur.fetchall()
rows[:3]
# Out:
# ((12.0,), (11.0,), (15.0,))

# %%
df = pd.DataFrame(list(rows), columns=['size'])
df.head()
# Out:
#    size
# 0  12.0
# 1  11.0
# 2  15.0
# 3  14.0
# 4   6.2
